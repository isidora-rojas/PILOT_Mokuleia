# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt

# %%
bulk_df = pd.read_parquet('../data_interim/bulk_df.parquet')
binned_df = pd.read_parquet('../data_interim/binned2H0.parquet')
# Out:
#     H0_mean    H0_std  H0_count     L0_mean     L0_std  L0_count    n_mean  \
# 0  0.576098  0.012128         8  119.378614  12.792140         8 -0.090554
# 1  0.658773  0.027603        77  135.119543  35.934925        77 -0.089376
# 2  0.751944  0.028076       117  121.206032  30.783891       117 -0.085279
# 3  0.848764  0.029844       102  104.655226  35.604861       102 -0.081251
# 4  0.952826  0.029349       173   90.151623  22.964306       173 -0.076940
#
#       n_std  n_count  H0L0_mean  ...  steepness_count  setdown_mean  \
# 0  0.011189        8  68.725396  ...                8 -2.386840e-09
# 1  0.013597       77  88.960679  ...               77 -3.620465e-09
# 2  0.017908      117  91.117089  ...              117 -7.806208e-09
# 3  0.018028      102  88.442928  ...              102 -2.887473e-08
# 4  0.019946      173  85.881294  ...              173 -3.900670e-08
#
#     setdown_std  setdown_count    H0_sem    L0_sem     n_sem  H0L0_sem  \
# 0  1.007913e-09              8  0.004288  4.522704  0.003956  2.467334
# 1  2.906515e-09             77  0.003146  4.095165  0.001550  2.720847
# 2  1.568104e-08            117  0.002596  2.845972  0.001656  2.149763
# 3  1.100392e-07            102  0.002955  3.525407  0.001785  2.881673
# 4  1.798346e-07            173  0.002231  1.745944  0.001516  1.685459
#
#    steepness_sem   setdown_sem
# 0       0.000223  3.563510e-10
# 1       0.000134  3.312281e-10
# 2       0.000120  1.449713e-09
# 3       0.000264  1.089550e-08
# 4       0.000199  1.367257e-08
#
# [5 rows x 24 columns]
